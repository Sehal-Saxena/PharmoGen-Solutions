# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.1.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.11.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
import pandas as pd
df = pd.read_csv('bioactivity_data_3class_pIC50_pubchem_fp.csv')


X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
X.shape
# Out:
# (86, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (86, 185)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:20<00:00,  2.05it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 408
# [LightGBM] [Info] Number of data points in the train set: 68, number of used features: 136
# [LightGBM] [Info] Start training from score 4.737326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
# 100%|██████████| 42/42 [00:21<00:00,  1.92it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000096 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 408
# [LightGBM] [Info] Number of data points in the train set: 68, number of used features: 136
# [LightGBM] [Info] Start training from score 4.737326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# Performance table of the training set (80% subset)
models_train
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          11035067105679291522487857939223618545338949541...
# LarsCV                        10816767416449666491087620538308636048599739163...
# KernelRidge                                                                15.44
# DummyRegressor                                                              1.57
# ElasticNet                                                                  1.57
# LassoLars                                                                   1.57
# Lasso                                                                       1.57
# LassoLarsCV                                                                 1.34
# KNeighborsRegressor                                                         1.20
# OrthogonalMatchingPursuitCV                                                 1.19
# HistGradientBoostingRegressor                                               1.17
# LGBMRegressor                                                               1.17
# ElasticNetCV                                                                1.17
# LassoCV                                                                     1.17
# BayesianRidge                                                               1.15
# GammaRegressor                                                              1.14
# TweedieRegressor                                                            1.14
# NuSVR                                                                       1.13
# SVR                                                                         1.13
# OrthogonalMatchingPursuit                                                   1.09
# PoissonRegressor                                                            1.07
# SGDRegressor                                                                1.06
# RidgeCV                                                                     1.06
# AdaBoostRegressor                                                           1.06
# BaggingRegressor                                                            1.06
# RandomForestRegressor                                                       1.05
# PassiveAggressiveRegressor                                                  1.04
# HuberRegressor                                                              1.02
# LinearSVR                                                                   1.02
# Ridge                                                                       1.02
# GradientBoostingRegressor                                                   1.02
# MLPRegressor                                                                1.01
# LinearRegression                                                            1.00
# TransformedTargetRegressor                                                  1.00
# XGBRegressor                                                                1.00
# GaussianProcessRegressor                                                    1.00
# DecisionTreeRegressor                                                       1.00
# ExtraTreeRegressor                                                          1.00
# ExtraTreesRegressor                                                         1.00
#
#                                                                        R-Squared  \
# Model
# Lars                          -1943489430552472232433400973450315687988996502...
# LarsCV                        -1905042619613523363872711033960850758999262686...
# KernelRidge                                                               -24.43
# DummyRegressor                                                              0.00
# ElasticNet                                                                  0.00
# LassoLars                                                                   0.00
# Lasso                                                                       0.00
# LassoLarsCV                                                                 0.40
# KNeighborsRegressor                                                         0.65
# OrthogonalMatchingPursuitCV                                                 0.67
# HistGradientBoostingRegressor                                               0.70
# LGBMRegressor                                                               0.70
# ElasticNetCV                                                                0.70
# LassoCV                                                                     0.71
# BayesianRidge                                                               0.73
# GammaRegressor                                                              0.76
# TweedieRegressor                                                            0.76
# NuSVR                                                                       0.77
# SVR                                                                         0.78
# OrthogonalMatchingPursuit                                                   0.83
# PoissonRegressor                                                            0.88
# SGDRegressor                                                                0.89
# RidgeCV                                                                     0.89
# AdaBoostRegressor                                                           0.90
# BaggingRegressor                                                            0.90
# RandomForestRegressor                                                       0.92
# PassiveAggressiveRegressor                                                  0.93
# HuberRegressor                                                              0.96
# LinearSVR                                                                   0.97
# Ridge                                                                       0.97
# GradientBoostingRegressor                                                   0.97
# MLPRegressor                                                                0.99
# LinearRegression                                                            0.99
# TransformedTargetRegressor                                                  0.99
# XGBRegressor                                                                0.99
# GaussianProcessRegressor                                                    0.99
# DecisionTreeRegressor                                                       0.99
# ExtraTreeRegressor                                                          0.99
# ExtraTreesRegressor                                                         0.99
#
#                                                                   RMSE  \
# Model
# Lars                          1310478949252128688287357350216466432.00
# LarsCV                        1297452017258212993793212413038821376.00
# KernelRidge                                                       4.74
# DummyRegressor                                                    0.94
# ElasticNet                                                        0.94
# LassoLars                                                         0.94
# Lasso                                                             0.94
# LassoLarsCV                                                       0.73
# KNeighborsRegressor                                               0.56
# OrthogonalMatchingPursuitCV                                       0.54
# HistGradientBoostingRegressor                                     0.52
# LGBMRegressor                                                     0.52
# ElasticNetCV                                                      0.51
# LassoCV                                                           0.51
# BayesianRidge                                                     0.49
# GammaRegressor                                                    0.46
# TweedieRegressor                                                  0.46
# NuSVR                                                             0.45
# SVR                                                               0.44
# OrthogonalMatchingPursuit                                         0.38
# PoissonRegressor                                                  0.33
# SGDRegressor                                                      0.32
# RidgeCV                                                           0.31
# AdaBoostRegressor                                                 0.30
# BaggingRegressor                                                  0.30
# RandomForestRegressor                                             0.27
# PassiveAggressiveRegressor                                        0.25
# HuberRegressor                                                    0.18
# LinearSVR                                                         0.16
# Ridge                                                             0.16
# GradientBoostingRegressor                                         0.16
# MLPRegressor                                                      0.11
# LinearRegression                                                  0.08
# TransformedTargetRegressor                                        0.08
# XGBRegressor                                                      0.08
# GaussianProcessRegressor                                          0.08
# DecisionTreeRegressor                                             0.08
# ExtraTreeRegressor                                                0.08
# ExtraTreesRegressor                                               0.08
#
#                                Time Taken
# Model
# Lars                                 0.15
# LarsCV                               0.53
# KernelRidge                          0.02
# DummyRegressor                       0.03
# ElasticNet                           0.04
# LassoLars                            0.03
# Lasso                                0.04
# LassoLarsCV                          0.08
# KNeighborsRegressor                  0.11
# OrthogonalMatchingPursuitCV          0.04
# HistGradientBoostingRegressor        1.29
# LGBMRegressor                        0.12
# ElasticNetCV                         8.30
# LassoCV                              6.48
# BayesianRidge                        0.03
# GammaRegressor                       0.12
# TweedieRegressor                     0.35
# NuSVR                                0.03
# SVR                                  0.04
# OrthogonalMatchingPursuit            0.03
# PoissonRegressor                     0.22
# SGDRegressor                         0.07
# RidgeCV                              0.06
# AdaBoostRegressor                    0.13
# BaggingRegressor                     0.05
# RandomForestRegressor                0.32
# PassiveAggressiveRegressor           0.03
# HuberRegressor                       0.21
# LinearSVR                            0.13
# Ridge                                0.04
# GradientBoostingRegressor            0.25
# MLPRegressor                         0.21
# LinearRegression                     0.04
# TransformedTargetRegressor           0.03
# XGBRegressor                         0.17
# GaussianProcessRegressor             0.09
# DecisionTreeRegressor                0.04
# ExtraTreeRegressor                   0.06
# ExtraTreesRegressor                  0.38

# %%
 #Performance table of the test set (20% subset)
models_test
# Out:
#                                                               Adjusted R-Squared  \
# Model
# Lars                          74168405660516833290534300912079823735624708618...
# LarsCV                        72703386152734147965050427619721311206478144372...
# LinearRegression                                      73063036037990828736512.00
# TransformedTargetRegressor                            73063036037990828736512.00
# GaussianProcessRegressor                                                    4.14
# KernelRidge                                                                 3.44
# MLPRegressor                                                                1.24
# LinearSVR                                                                   1.15
# LassoLars                                                                   1.13
# DummyRegressor                                                              1.13
# ElasticNet                                                                  1.13
# Lasso                                                                       1.13
# ExtraTreeRegressor                                                          1.11
# HuberRegressor                                                              1.11
# DecisionTreeRegressor                                                       1.10
# Ridge                                                                       1.09
# ExtraTreesRegressor                                                         1.09
# BaggingRegressor                                                            1.09
# LassoLarsCV                                                                 1.08
# XGBRegressor                                                                1.08
# PassiveAggressiveRegressor                                                  1.07
# GradientBoostingRegressor                                                   1.06
# OrthogonalMatchingPursuit                                                   1.05
# AdaBoostRegressor                                                           1.05
# RandomForestRegressor                                                       1.04
# NuSVR                                                                       1.04
# SGDRegressor                                                                1.04
# SVR                                                                         1.04
# LGBMRegressor                                                               1.04
# HistGradientBoostingRegressor                                               1.04
# PoissonRegressor                                                            1.04
# RidgeCV                                                                     1.04
# LassoCV                                                                     1.03
# ElasticNetCV                                                                1.03
# GammaRegressor                                                              1.03
# OrthogonalMatchingPursuitCV                                                 1.03
# BayesianRidge                                                               1.03
# TweedieRegressor                                                            1.03
# KNeighborsRegressor                                                         1.02
#
#                                                                        R-Squared  \
# Model
# Lars                          -7329583618215781660474975415477587755142218582...
# LarsCV                        -7184805219799609916546159905948929578051957796...
# LinearRegression                                    -722034709081321107357696.00
# TransformedTargetRegressor                          -722034709081321107357696.00
# GaussianProcessRegressor                                                  -30.03
# KernelRidge                                                               -23.14
# MLPRegressor                                                               -1.37
# LinearSVR                                                                  -0.48
# LassoLars                                                                  -0.31
# DummyRegressor                                                             -0.31
# ElasticNet                                                                 -0.31
# Lasso                                                                      -0.31
# ExtraTreeRegressor                                                         -0.12
# HuberRegressor                                                             -0.09
# DecisionTreeRegressor                                                      -0.04
# Ridge                                                                       0.08
# ExtraTreesRegressor                                                         0.09
# BaggingRegressor                                                            0.15
# LassoLarsCV                                                                 0.18
# XGBRegressor                                                                0.19
# PassiveAggressiveRegressor                                                  0.34
# GradientBoostingRegressor                                                   0.40
# OrthogonalMatchingPursuit                                                   0.51
# AdaBoostRegressor                                                           0.53
# RandomForestRegressor                                                       0.56
# NuSVR                                                                       0.56
# SGDRegressor                                                                0.57
# SVR                                                                         0.57
# LGBMRegressor                                                               0.58
# HistGradientBoostingRegressor                                               0.58
# PoissonRegressor                                                            0.62
# RidgeCV                                                                     0.64
# LassoCV                                                                     0.67
# ElasticNetCV                                                                0.68
# GammaRegressor                                                              0.70
# OrthogonalMatchingPursuitCV                                                 0.73
# BayesianRidge                                                               0.74
# TweedieRegressor                                                            0.74
# KNeighborsRegressor                                                         0.78
#
#                                                                             RMSE  \
# Model
# Lars                          81628688871404573026899589446801479706601324544...
# LarsCV                        80818478190828114906285877870911277620241052467...
# LinearRegression                                                 810181284419.37
# TransformedTargetRegressor                                       810181284419.37
# GaussianProcessRegressor                                                    5.31
# KernelRidge                                                                 4.68
# MLPRegressor                                                                1.47
# LinearSVR                                                                   1.16
# LassoLars                                                                   1.09
# DummyRegressor                                                              1.09
# ElasticNet                                                                  1.09
# Lasso                                                                       1.09
# ExtraTreeRegressor                                                          1.01
# HuberRegressor                                                              1.00
# DecisionTreeRegressor                                                       0.97
# Ridge                                                                       0.92
# ExtraTreesRegressor                                                         0.91
# BaggingRegressor                                                            0.88
# LassoLarsCV                                                                 0.87
# XGBRegressor                                                                0.86
# PassiveAggressiveRegressor                                                  0.78
# GradientBoostingRegressor                                                   0.74
# OrthogonalMatchingPursuit                                                   0.67
# AdaBoostRegressor                                                           0.65
# RandomForestRegressor                                                       0.63
# NuSVR                                                                       0.63
# SGDRegressor                                                                0.63
# SVR                                                                         0.62
# LGBMRegressor                                                               0.62
# HistGradientBoostingRegressor                                               0.62
# PoissonRegressor                                                            0.59
# RidgeCV                                                                     0.57
# LassoCV                                                                     0.55
# ElasticNetCV                                                                0.54
# GammaRegressor                                                              0.52
# OrthogonalMatchingPursuitCV                                                 0.50
# BayesianRidge                                                               0.49
# TweedieRegressor                                                            0.48
# KNeighborsRegressor                                                         0.44
#
#                                Time Taken
# Model
# Lars                                 0.14
# LarsCV                               0.52
# LinearRegression                     0.04
# TransformedTargetRegressor           0.02
# GaussianProcessRegressor             0.03
# KernelRidge                          0.03
# MLPRegressor                         0.16
# LinearSVR                            0.11
# LassoLars                            0.02
# DummyRegressor                       0.04
# ElasticNet                           0.02
# Lasso                                0.04
# ExtraTreeRegressor                   0.03
# HuberRegressor                       0.07
# DecisionTreeRegressor                0.06
# Ridge                                0.02
# ExtraTreesRegressor                  0.25
# BaggingRegressor                     0.06
# LassoLarsCV                          0.06
# XGBRegressor                         0.13
# PassiveAggressiveRegressor           0.02
# GradientBoostingRegressor            0.15
# OrthogonalMatchingPursuit            0.02
# AdaBoostRegressor                    0.14
# RandomForestRegressor                0.26
# NuSVR                                0.02
# SGDRegressor                         0.02
# SVR                                  0.02
# LGBMRegressor                        0.09
# HistGradientBoostingRegressor        0.12
# PoissonRegressor                     0.34
# RidgeCV                              0.02
# LassoCV                              8.14
# ElasticNetCV                        10.01
# GammaRegressor                       0.33
# OrthogonalMatchingPursuitCV          0.03
# BayesianRidge                        0.05
# TweedieRegressor                     0.20
# KNeighborsRegressor                  0.02

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
